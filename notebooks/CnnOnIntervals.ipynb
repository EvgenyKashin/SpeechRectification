# %%
import pandas as pd
import numpy as np
import librosa
import librosa.display
from matplotlib.pyplot import specgram
import matplotlib.pyplot as plt
import pickle
import gzip
from tqdm import tqdm_notebook, tqdm

# %matplotlib inline

# %% [markdown]
# # Reading dataset

# %%
with gzip.open('../cache/dataset.pkl.gz', 'rb') as f:
    X, y = pickle.load(f)

# %%
len(X), len(y)
# Out:
# (12202, 12202)

# %%
a = [x for x, y_ in zip(X, y) if y_ == 0]
b = [x for x, y_ in zip(X, y) if y_ == 1]
c = [x for x, y_ in zip(X, y) if y_ == 2]

# %%
c = [np.array(x) for x in c]

# %%
len(a), len(b), len(c)
# Out:
# (1835, 325, 10042)

# %%
from IPython.display import Audio, display

# %%
wids = [Audio(a[i], rate=22050) for i in np.random.randint(0, len(a), 3)]

# %%
for w in wids:
    display(w)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wids = [Audio(b[i], rate=22050) for i in np.random.randint(0, len(b), 3)]

# %%
for w in wids:
    display(w)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
wids = [Audio(c[i], rate=22050) for i in np.random.randint(0, len(c), 3)]

# %%
for w in wids:
    display(w)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # New

# %%
from scipy.fftpack import fft
from scipy import signal

# %%
sample_rate = 22050

# %%
def log_specgram(audio, sample_rate, window_size=20,
                 step_size=10, eps=1e-10):
    nperseg = int(round(window_size * sample_rate / 1e3))
    noverlap = int(round(step_size * sample_rate / 1e3))
    freqs, times, spec = signal.spectrogram(audio,
                                    fs=sample_rate,
                                    window='hann',
                                    nperseg=nperseg,
                                    noverlap=noverlap,
                                    detrend=False)
    return freqs, times, np.log(spec.T.astype(np.float32) + eps)

# %%
samples = c[32]

# %%
Audio(samples, rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# %%timeit
freqs, times, spectrogram = log_specgram(samples, sample_rate)
# Out:
# 710 µs ± 22.7 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
freqs, times, spectrogram = log_specgram(samples, sample_rate)

# %%
len(freqs)
# Out:
# 221

# %%
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, len(samples) / sample_rate, len(samples)), samples)

ax2 = fig.add_subplot(212)
ax2.imshow(spectrogram.T, aspect='auto', origin='lower', 
           extent=[times.min(), times.max(), freqs.min(), freqs.max()])
ax2.set_yticks(freqs[::16])
ax2.set_xticks(times[::16])
ax2.set_title('Spectrogram')
ax2.set_ylabel('Freqs in Hz')
ax2.set_xlabel('Seconds')
# Out:
# Text(0.5,0,'Seconds')

# %% [markdown]
# ### Resample

# %% [markdown]
# https://librosa.github.io/librosa/generated/librosa.core.resample.html

# %%
new_sample_rate = 8000

# %%
# %%time
samples_r = librosa.resample(samples, sample_rate, new_sample_rate)
# Out:
# CPU times: user 977 ms, sys: 5.64 ms, total: 982 ms
# Wall time: 1.04 s

# %%
# %%timeit
freqs, times, spectrogram = log_specgram(samples_r, new_sample_rate)
# Out:
# 351 µs ± 15.9 µs per loop (mean ± std. dev. of 7 runs, 1000 loops each)

# %%
freqs, times, spectrogram = log_specgram(samples_r, new_sample_rate)

# %%
len(freqs)
# Out:
# 81

# %%
fig = plt.figure(figsize=(14, 8))
ax1 = fig.add_subplot(211)
ax1.set_title('Raw wave')
ax1.set_ylabel('Amplitude')
ax1.plot(np.linspace(0, len(samples_r) / 8000, len(samples_r)), samples_r)

ax2 = fig.add_subplot(212)
ax2.imshow(spectrogram.T, aspect='auto', origin='lower', 
           extent=[times.min(), times.max(), freqs.min(), freqs.max()])
ax2.set_yticks(freqs[::16])
ax2.set_xticks(times[::16])
ax2.set_title('Spectrogram')
ax2.set_ylabel('Freqs in Hz')
ax2.set_xlabel('Seconds')
# Out:
# Text(0.5,0,'Seconds')

# %%
spectrogram.shape
# Out:
# (29, 81)

# %%
Audio(samples, rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(samples_r, rate=new_sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# From this tutorial
# https://github.com/librosa/librosa/blob/master/examples/LibROSA%20demo.ipynb
S = librosa.feature.melspectrogram(samples, sr=sample_rate, n_mels=128)

# Convert to log scale (dB). We'll use the peak power (max) as reference.
log_S = librosa.power_to_db(S, ref=np.max)

plt.figure(figsize=(12, 4))
librosa.display.specshow(log_S, sr=sample_rate, x_axis='time', y_axis='mel')
plt.title('Mel power spectrogram ')
plt.colorbar(format='%+02.0f dB')
plt.tight_layout()

# %%
log_S.shape
# Out:
# (128, 13)

# %%
mfcc = librosa.feature.mfcc(S=log_S, n_mfcc=13)

# Let's pad on the first and second deltas while we're at it
delta2_mfcc = librosa.feature.delta(mfcc, order=2)

plt.figure(figsize=(12, 4))
librosa.display.specshow(delta2_mfcc)
plt.ylabel('MFCC coeffs')
plt.xlabel('Time')
plt.title('MFCC')
plt.colorbar()
plt.tight_layout()

# %% [markdown]
# ## FFT

# %%
plt.plot(np.abs(fft(samples))[:len(samples)//2])
# plt.ylim(0, 10)

# %%
def custom_fft(y, fs):
#     T = 1.0 / fs
    N = y.shape[0]
    yf = fft(y)
#     xf = np.linspace(0.0, 1.0/(2.0*T), N//2)
#     vals = 2.0/N * np.abs(yf[0:N//2]) 
#     FFT is also complex, to we take just the real part (abs)
    vals = np.abs(yf[0:N//2])
    return vals

# %% [markdown]
# ### Before and after resample

# %%
Audio(samples, rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(samples_r, rate=new_sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
vals = custom_fft(samples, sample_rate)
plt.figure(figsize=(12, 4))
plt.title('FFT of recording sampled with ' + str(sample_rate) + ' Hz')
plt.plot(range(len(vals)), vals)
plt.xlabel('Frequency')
plt.grid()
plt.show()

# %%
vals = custom_fft(samples_r, new_sample_rate)
plt.figure(figsize=(12, 4))
plt.title('FFT of recording sampled with ' + str(new_sample_rate) + ' Hz')
plt.plot(range(len(vals)), vals)
plt.xlabel('Frequency')
plt.grid()
plt.show()

# %% [markdown]
# ## Different slices

# %%
vals = custom_fft(samples, sample_rate)
plt.figure(figsize=(12, 4))
plt.title('FFT of recording sampled with ' + str(sample_rate) + ' Hz')
plt.plot(range(len(vals)), vals)
plt.xlabel('Frequency')
plt.grid()
plt.show()

# %%
for i, aa in enumerate(a[:3]):
    vals = custom_fft(aa, new_sample_rate)
    plt.figure(figsize=(12, 4))
    plt.title('FFT of {}'.format(i))
    plt.plot(range(len(vals)), vals)
    plt.xlabel('Frequency')
    plt.grid()
    plt.show()

# %%
Audio(a[0], rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(a[1], rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
Audio(a[2], rate=sample_rate)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %% [markdown]
# # Feature extratction

# %%
X = [x if type(x) == type(np.array([])) else np.array(x) for x in X]

# %%
_, _, s = log_specgram(a[0], sample_rate)

# %%
plt.imshow(s)

# %%
s.shape
# Out:
# (28, 221)

# %%
# todo - def extract_features

# %%
def extract_features(x):
    _, _, spec = log_specgram(x, sample_rate)
    return np.expand_dims(spec, -1)

# %%
X_spec = []
for x in tqdm(X):
    spec = extract_features(x)
    X_spec.append(spec)
X_spec = np.array(X_spec)
# Out:
# 100%|██████████| 12202/12202 [00:10<00:00, 1150.04it/s]

# %% [markdown]
# # Cnn model

# %%
from sklearn.model_selection import cross_val_score, train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.metrics import classification_report

# %%
import keras
from keras.models import Sequential
from keras.layers import Conv2D, MaxPool2D, Dense, Flatten, Dropout
from keras.utils import to_categorical
# Out:
# Using TensorFlow backend.
# /home/evgeny/miniconda3/lib/python3.6/importlib/_bootstrap.py:219: RuntimeWarning: compiletime version 3.5 of module 'tensorflow.python.framework.fast_tensor_util' does not match runtime version 3.6
#   return f(*args, **kwds)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_spec, y, test_size=0.1,
                                                    stratify=y, random_state=10)

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.1,
                                                    stratify=y_train, random_state=10)

# %%
y_train, y_val, y_test = to_categorical(y_train), to_categorical(y_val),\
                         to_categorical(y_test)

# %%
vc = pd.Series.value_counts(np.argmax(y_train, 1), True)
vc
# Out:
# 2    0.822910
# 0    0.150374
# 1    0.026715
# dtype: float64

# %%
frac = 0.75

# %%
vc[2] / vc[0] * frac - 1, vc[2] / vc[1] * frac - 1
# Out:
# (3.1043068640646032, 22.102272727272727)

# %%
X_train = np.vstack((X_train, np.repeat(X_train[np.argmax(y_train, 1) == 0], 3, 0)))
y_train = np.vstack((y_train, np.repeat(y_train[np.argmax(y_train, 1) == 0], 3, 0)))

# %%
X_train = np.vstack((X_train, np.repeat(X_train[np.argmax(y_train, 1) == 1], 22, 0)))
y_train = np.vstack((y_train, np.repeat(y_train[np.argmax(y_train, 1) == 1], 22, 0)))

# %%
pd.Series.value_counts(np.argmax(y_train, 1), True)
# Out:
# 2    0.403613
# 1    0.301370
# 0    0.295017
# dtype: float64

# %% [markdown]
# ---

# %%
model = Sequential()
model.add(Conv2D(32, 3, input_shape=X_train[0].shape, activation='relu'))
model.add(MaxPool2D())
model.add(Conv2D(32, 3, activation='relu'))
model.add(MaxPool2D())
model.add(Conv2D(32, 3, activation='relu'))
model.add(MaxPool2D())
model.add(Flatten())
model.add(Dense(100, activation='relu'))
model.add(Dropout(0.4))
model.add(Dense(3, activation='softmax'))

model.compile('adam', 'categorical_crossentropy')

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 26, 219, 32)       320
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 13, 109, 32)       0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 11, 107, 32)       9248
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 5, 53, 32)         0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 3, 51, 32)         9248
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 1, 25, 32)         0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 800)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 100)               80100
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 100)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 3)                 303
# =================================================================
# Total params: 99,219
# Trainable params: 99,219
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Predict without training

# %%
X_val[0].shape
# Out:
# (28, 221, 1)

# %%
pr = model.predict_classes(np.array(X_val), batch_size=128, verbose=1)
# Out:
# 1099/1099 [==============================] - 3s 3ms/step

# %%
pr = pr.ravel()

# %%
pd.Series.value_counts(pr)
# Out:
# 1    1099
# dtype: int64

# %%
accuracy_score(np.argmax(y_val, 1), pr)
# Out:
# 0.026387625113739762

# %%
print(classification_report(np.argmax(y_val, 1), pr))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.00      0.00      0.00       165
#           1       0.03      1.00      0.05        29
#           2       0.00      0.00      0.00       905
#
# avg / total       0.00      0.03      0.00      1099
# /home/evgeny/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %% [markdown]
# ## Training

# %%
pd.Series.value_counts(np.argmax(y_test, 1), True)
# Out:
# 2    0.823096
# 0    0.150696
# 1    0.026208
# dtype: float64

# %%
hist = model.fit(X_train, y_train, batch_size=128, epochs=3,
#                  class_weight={0: 15, 1: 35, 2: 1},
                 validation_data=(X_val, y_val))
# Out:
# Train on 20148 samples, validate on 1099 samples
# Epoch 1/3
# 20148/20148 [==============================] - 195s 10ms/step - loss: 0.7537 - val_loss: 0.7114
# Epoch 2/3
# 20148/20148 [==============================] - 190s 9ms/step - loss: 0.6247 - val_loss: 0.5541
# Epoch 3/3
# 20148/20148 [==============================] - 180s 9ms/step - loss: 0.5604 - val_loss: 0.5239

# %%
model.save('../cache/model.h5')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-101-1bb1ce31578a> in <module>()
# ----> 1 model.save('../cache/model.h5')
#
# ~/miniconda3/lib/python3.6/site-packages/keras/engine/topology.py in save(self, filepath, overwrite, include_optimizer)
#    2554         """
#    2555         from ..models import save_model
# -> 2556         save_model(self, filepath, overwrite, include_optimizer)
#    2557
#    2558     def save_weights(self, filepath, overwrite=True):
#
# ~/miniconda3/lib/python3.6/site-packages/keras/models.py in save_model(model, filepath, overwrite, include_optimizer)
#      55
#      56     if h5py is None:
# ---> 57         raise ImportError('`save_model` requires h5py.')
#      58
#      59     def get_json_type(obj):
#
# ImportError: `save_model` requires h5py.

# %%
pr = model.predict_classes(X_val, batch_size=128, verbose=1)
# Out:
# 1099/1099 [==============================] - 3s 3ms/step

# %%
pr = pr.ravel()

# %%
pd.Series.value_counts(pr)
# Out:
# 2    743
# 0    214
# 1    142
# dtype: int64

# %%
accuracy_score(np.argmax(y_val, 1), pr)
# Out:
# 0.78798908098271159

# %%
cm = confusion_matrix(np.argmax(y_val, 1), pr)

# %%
cm
# Out:
# array([[131,   9,  25],
#        [  4,  21,   4],
#        [ 79, 112, 714]])

# %%
print(classification_report(np.argmax(y_val, 1), pr))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.61      0.79      0.69       165
#           1       0.15      0.72      0.25        29
#           2       0.96      0.79      0.87       905
#
# avg / total       0.89      0.79      0.82      1099

# %%
# %time model.predict(X_val[:10, :, :, :])
# Out:
# CPU times: user 71.6 ms, sys: 4.28 ms, total: 75.9 ms
# Wall time: 28.3 ms
# array([[  9.45696533e-01,   2.80384663e-02,   2.62651071e-02],
#        [  1.42702938e-03,   7.05014390e-04,   9.97867942e-01],
#        [  2.11380199e-01,   5.69414645e-02,   7.31678247e-01],
#        [  2.58194894e-01,   1.17701568e-01,   6.24103606e-01],
#        [  4.57001030e-01,   1.70158204e-02,   5.25983095e-01],
#        [  1.38156908e-02,   1.82765478e-03,   9.84356701e-01],
#        [  9.52588558e-01,   3.66963223e-02,   1.07152108e-02],
#        [  3.09247404e-01,   5.89647926e-02,   6.31787777e-01],
#        [  7.29493648e-02,   4.64343000e-03,   9.22407210e-01],
#        [  3.58688496e-02,   7.09430501e-02,   8.93188059e-01]], dtype=float32)

# %%
plt.hist(np.argmax(y_test, 1), bins=3);

# %%
plt.hist(pr, bins=3);

# %%
accuracy_score(np.argmax(y_test, 1), [2] * len(y_test))
# Out:
# 0.82309582309582308

# %%
model.get_weights()[0].shape
# Out:
# (3, 3, 1, 32)

# %%
plt.imshow(model.get_weights()[0][:, :, 0, 4])
plt.gray()

# %% [markdown]
# # Testing on new data

# %%
def get_praat_annotations(paths):
    dfs = []
    for path in paths:
        with open(path) as f:
            annotation = [l.strip() for l in f.readlines()]
            
        indxs = [i for i, l in enumerate(annotation) if l == '"IntervalTier"']
        annotation = annotation[indxs[0] + 5:indxs[1] if len(indxs) > 1\
                                else len(annotation)]
        annotation_dicts = []

        for s, e, l in zip(annotation[0::3], annotation[1::3], annotation[2::3]):
            annotation_dicts.append({
                'start': float(s),
                'finish': float(e),
                'label': l.replace('"', ''),
                'length': float(e) - float(s)
            })
        df = pd.DataFrame(annotation_dicts)
        dfs.append(df)
    return dfs

test_annotation = get_praat_annotations(['../annotations/arhis1.TextGrid'])

# %%
test_audio, sr = librosa.load('../audio/arhis1.m4a')

# %%
interval_time = 0.3
interval_step = 0.1

interval_len, step_len = librosa.time_to_samples(interval_time)[0],\
                 librosa.time_to_samples(interval_step)[0]

# %%
interval_len, step_len
# Out:
# (6615, 2205)

# %%
test_annotation[0][test_annotation[0].label == 'b'].length.describe()
# Out:
# count    0.0
# mean     NaN
# std      NaN
# min      NaN
# 25%      NaN
# 50%      NaN
# 75%      NaN
# max      NaN
# Name: length, dtype: float64

# %%
librosa.time_to_samples(0.18)
# Out:
# array([3969])

# %%
def get_intersection_of_intervals(a, b):
    # a - fixed, b - random, a[0] - x1, a[1] - y1
    int_len = a[1] - a[0]
    
    if b[1] > a[0]:
        right_int = max(a[1] - b[1], 0)
    else:
        right_int = int_len
    
    if b[0] < a[1]:
        left_int = max(b[0] - a[0], 0)
    else:
        left_int = int_len
    return int_len - right_int - left_int

# %%
get_intersection_of_intervals((10, 15), (12, 14))
# Out:
# 2

# %%
get_intersection_of_intervals((10, 15), (15, 16))
# Out:
# 0

# %%
len(test_audio)
# Out:
# 6994400

# %%
list(range(0, 10, 2))
# Out:
# [0, 2, 4, 6, 8]

# %%
audio_intervals = [(x, x + interval_len) for x in range(0, len(test_audio), step_len)][:-4]

# %%
len(audio_intervals)
# Out:
# 3169

# %%
set([y - x for x, y in audio_intervals])
# Out:
# {6615}

# %%
interval_len
# Out:
# 6615

# %%
min_delta = interval_len // 6

# %%
min_delta
# Out:
# 1102

# %%
def match_intervals(annotation, audio, labels, sr=22050):
    audio_intervals = [(x, x + interval_len) for x in range(0, len(audio), step_len)][:-4]
    targets = []
    label_map = {'a': 0, 'b': 1, 'c': 2}
    for interval in audio_intervals:
        value = 0
        for label in labels:
            l = label_map[label]
            start_samples_indxs = librosa.time_to_samples(annotation[annotation.label ==\
                                                                  label].start.values, sr)
            finish_samples_indxs = librosa.time_to_samples(annotation[annotation.label ==\
                                                                   label].finish.values,
                                                                   sr)
            for s, f in zip(start_samples_indxs, finish_samples_indxs):
                value = get_intersection_of_intervals(interval, (s, f))
                if value > min_delta:
                    break
                else:
                    value = 0
            if value != 0:
                break
        if value != 0:
            targets.append(l)
        else:
            targets.append(2)
    return audio_intervals, targets

# %% [markdown]
# Идем с шагом step_len и берем интервалы по interval_len, проверяем - с каким из размеченных интервалов пересекается наш интервал больше чем на min_delta и присваиваем его метку

# %% [markdown]
# Не учитываются случаи, когда идет несколько подряд "эээ" и "нуу", и так как метки отсортированы, пока интервал будет касаться левой стороной первого "эээ", а правой "нуу", то будет присвоена метка "эээ". **TODO**

# %%
# %%time
test_intervals, test_targets = match_intervals(test_annotation[0], test_audio, ['a', 'b'])
# Out:
# CPU times: user 11.8 s, sys: 58.2 ms, total: 11.8 s
# Wall time: 12 s

# %%
len(test_intervals), len(test_targets)
# Out:
# (3169, 3169)

# %%
pd.Series.value_counts(test_targets)
# Out:
# 2    2862
# 0     307
# dtype: int64

# %%
plt.plot(test_targets[:100])

# %%
# def get_label_data(annotation, audio, labels, sr=22050):
#     # по дефолту все 2го класса
#     data = pd.Series(index=np.arange(0, len(audio) - interval_len, step_len), data=2)
#     label_map = {'a': 0, 'b': 1, 'c': 2}
#     for label in labels:
#         l = label_map[label]
#         start_samples_indxs = librosa.time_to_samples(annotation[annotation.label ==\
#                                                               label].start.values, sr)
#         finish_samples_indxs = librosa.time_to_samples(annotation[annotation.label ==\
#                                                                label].finish.values, sr)
#         for s, f in zip(start_samples_indxs, finish_samples_indxs):
#             s = int(np.round(s / step_len)) * step_len
#             f = (int(np.round(f / step_len)) - 2) * step_len
#             # вычитаем 2 потому что f - это конец интервала, в Series мы заносим метку для 
#             # начала  интервала, длина интервала 2 * step, поэтому нужно вычесть 2
#             data[(data.index >= s) & (data.index <= f)] = l
#     return data

# %%
len(test_audio)
# Out:
# 6994400

# %%
test_samples = [test_audio[s:f] for s, f in test_intervals]

# %%
test_intervals[-1]
# Out:
# (6985440, 6992055)

# %%
test_samples[-1].shape
# Out:
# (6615,)

# %%
len(test_samples)
# Out:
# 3169

# %%
test_features = np.stack([extract_features(x) for x in tqdm(test_samples)])
# Out:
#   0%|          | 0/3169 [00:00<?, ?it/s]
#   2%|▏         | 67/3169 [00:00<00:04, 654.55it/s]
#   4%|▍         | 140/3169 [00:00<00:04, 690.76it/s]
#   7%|▋         | 219/3169 [00:00<00:04, 721.74it/s]
#   9%|▉         | 286/3169 [00:00<00:04, 708.11it/s]
#  12%|█▏        | 366/3169 [00:00<00:03, 723.11it/s]
#  14%|█▍        | 437/3169 [00:00<00:03, 720.33it/s]
#  16%|█▌        | 506/3169 [00:00<00:03, 714.14it/s]
#  18%|█▊        | 572/3169 [00:00<00:03, 706.78it/s]
#  20%|██        | 638/3169 [00:00<00:03, 697.33it/s]
#  22%|██▏       | 703/3169 [00:01<00:03, 689.33it/s]
#  24%|██▍       | 767/3169 [00:01<00:03, 677.18it/s]
#  26%|██▌       | 829/3169 [00:01<00:03, 666.96it/s]
#  28%|██▊       | 889/3169 [00:01<00:03, 653.48it/s]
#  30%|██▉       | 947/3169 [00:01<00:03, 642.37it/s]
#  32%|███▏      | 1003/3169 [00:01<00:03, 636.73it/s]
#  34%|███▎      | 1062/3169 [00:01<00:03, 632.79it/s]
#  35%|███▌      | 1119/3169 [00:01<00:03, 626.52it/s]
#  37%|███▋      | 1175/3169 [00:01<00:03, 622.91it/s]
#  39%|███▉      | 1237/3169 [00:01<00:03, 622.42it/s]
#  41%|████      | 1295/3169 [00:02<00:03, 619.07it/s]
#  43%|████▎     | 1352/3169 [00:02<00:02, 617.40it/s]
#  44%|████▍     | 1409/3169 [00:02<00:02, 612.29it/s]
#  46%|████▌     | 1465/3169 [00:02<00:02, 609.04it/s]
#  48%|████▊     | 1521/3169 [00:02<00:02, 605.16it/s]
#  50%|████▉     | 1576/3169 [00:02<00:02, 603.19it/s]
#  52%|█████▏    | 1641/3169 [00:02<00:02, 604.97it/s]
#  54%|█████▍    | 1706/3169 [00:02<00:02, 605.90it/s]
#  56%|█████▌    | 1765/3169 [00:02<00:02, 594.96it/s]
#  57%|█████▋    | 1819/3169 [00:03<00:02, 588.41it/s]
#  59%|█████▉    | 1869/3169 [00:03<00:02, 583.75it/s]
#  61%|██████    | 1919/3169 [00:03<00:02, 579.66it/s]
#  62%|██████▏   | 1973/3169 [00:03<00:02, 579.75it/s]
#  64%|██████▍   | 2029/3169 [00:03<00:01, 579.21it/s]
#  66%|██████▌   | 2088/3169 [00:03<00:01, 578.99it/s]
#  68%|██████▊   | 2143/3169 [00:03<00:01, 576.03it/s]
#  69%|██████▉   | 2198/3169 [00:03<00:01, 575.29it/s]
#  71%|███████   | 2255/3169 [00:03<00:01, 575.05it/s]
#  73%|███████▎  | 2309/3169 [00:04<00:01, 574.01it/s]
#  75%|███████▍  | 2371/3169 [00:04<00:01, 575.06it/s]
#  77%|███████▋  | 2428/3169 [00:04<00:01, 575.09it/s]
#  78%|███████▊  | 2485/3169 [00:04<00:01, 573.92it/s]
#  80%|████████  | 2541/3169 [00:04<00:01, 572.91it/s]
#  82%|████████▏ | 2603/3169 [00:04<00:00, 573.75it/s]
#  84%|████████▍ | 2660/3169 [00:04<00:00, 573.34it/s]
#  86%|████████▌ | 2728/3169 [00:04<00:00, 575.17it/s]
#  88%|████████▊ | 2788/3169 [00:04<00:00, 570.93it/s]
#  90%|████████▉ | 2843/3169 [00:05<00:00, 568.08it/s]
#  91%|█████████▏| 2899/3169 [00:05<00:00, 567.77it/s]
#  93%|█████████▎| 2952/3169 [00:05<00:00, 566.41it/s]
#  95%|█████████▌| 3012/3169 [00:05<00:00, 567.02it/s]
#  97%|█████████▋| 3072/3169 [00:05<00:00, 567.30it/s]
#  99%|█████████▊| 3128/3169 [00:05<00:00, 566.68it/s]
# 100%|██████████| 3169/3169 [00:05<00:00, 566.75it/s]

# %%
test_features.shape
# Out:
# (3169, 28, 221, 1)

# %%
test_predict = model.predict_classes(test_features, batch_size=128)

# %%
test_predict_pr = model.predict_proba(test_features, batch_size=128)

# %% [markdown]
# **TODO** сделать усреднение предикта с 1 влево 1 вправо интервалами

# %%
accuracy_score(test_targets, test_predict) # c 2мя cnn
# Out:
# 0.77563900284001264

# %%
accuracy_score(test_targets, [2] * len(test_predict))
# Out:
# 0.90312401388450614

# %%
print(classification_report(test_targets, test_predict)) # cnn
# Out:
#              precision    recall  f1-score   support
#
#           0       0.69      0.10      0.18       307
#           1       0.00      0.00      0.00         0
#           2       0.92      0.85      0.88      2862
#
# avg / total       0.90      0.78      0.81      3169
# /home/evgeny/miniconda3/lib/python3.6/site-packages/sklearn/metrics/classification.py:1137: UndefinedMetricWarning: Recall and F-score are ill-defined and being set to 0.0 in labels with no true samples.
#   'recall', 'true', average, warn_for)

# %%
# test_predict_new = 1 * (test_predict_pr[:, 1] > 0.95).astype(int)

# %%
test_predict_new = 2 - 2 * (test_predict_pr[:, 0] > 0.1).astype(int)

# %%
print(classification_report(test_data.values, test_predict_new))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.38      0.56      0.45        78
#           2       0.98      0.96      0.97      2036
#
# avg / total       0.96      0.95      0.95      2114

# %%
print(classification_report(test_targets, test_predict_new))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.43      0.29      0.35       307
#           2       0.93      0.96      0.94      2862
#
# avg / total       0.88      0.89      0.88      3169

# %%
plt.plot(test_predict_new[:2000], '--', label='pr', alpha=0.4)
plt.plot(test_targets[:2000], '-.', label='tr', alpha=0.4)
plt.legend()

# %% [markdown]
# ## Отображение результата

# %%
from PIL import Image
import os
import shutil

# %%
# os.rmdir('../cache/imgs/')
shutil.rmtree('../cache/imgs/')

# %%
os.mkdir('../cache/imgs')

# %%
1 / interval_step
# Out:
# 6.666666666666667

# %%
for i, (r, t) in enumerate(zip(test_predict_new, test_data.values)):
    im_r = np.zeros((32, 64, 3), dtype='uint8')
    if r == 0:
        im_r[:,:,0] = 255
    elif r == 2:
        im_r[...,2] = 255
    else:
        im_r[...,1] = 255
        
    im_t = np.zeros((32, 64, 3), dtype='uint8')
    if t == 0:
        im_t[:,:,0] = 255
    elif t == 2:
        im_t[...,2] = 255
    else:
        im_t[...,1] = 255
        
    im = np.vstack((im_r, im_t))
    im = Image.fromarray(im)
    im.save('../cache/imgs/test_{:04d}.png'.format(i + 2))
im.save('../cache/imgs/test_{:04d}.png'.format(0))
im.save('../cache/imgs/test_{:04d}.png'.format(1))

# %%
os.system('ffmpeg -r 6.666 -i ../cache/imgs/test_%04d.png -i ../audio/arhis1.mp3 -vcodec mpeg4 -y ../cache/a.mp4')
# Out:
# 0

# %% [markdown]
# ## Ручная корректировка шума

# %%
test_predict_new = test_predict_new.ravel()

# %%
# %%time
test_predict_new2 = []

start = False
for t, tn in zip(test_predict_new, np.append(test_predict_new[1:], [1])):
    if t == 0 and tn == 0 and not start:
        # если встретили 0 и следующий 0 и до этого не началось, включаем начало и доб-ем 0
        start = True
        test_predict_new2.append(0)
    elif t == 0 and tn == 0 and start:
        # если встретили 0 и следующий 0 и до этого началось, доб-ем 0 - мы в серии нулей
        test_predict_new2.append(0)
    elif t == 0 and tn != 0 and not start:
        # если встретили 0, а следующий не 0 и до этого не началось, значит шум, не 0 
        test_predict_new2.append(1)
    elif t == 0 and tn != 0 and start:
        # если встретили 0, а след. не 0 и до этого началось, значит 0, но начало в False
        start = False
        test_predict_new2.append(0)
    elif t == 1:
        # если встрили 1, добавляем 1
        test_predict_new2.append(1)
        start = False
    else:
        print(t, tn, start)
# Out:
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 0 False
# 2 0 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 0 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 2 False
# 2 1 False
# CPU times: user 647 ms, sys: 124 ms, total: 772 ms
# Wall time: 680 ms

# %%
pd.Series.value_counts(test_predict_new)
# Out:
# 2    1998
# 0     116
# dtype: int64

# %%
pd.Series.value_counts(test_predict_new2)
# Out:
# 1    66
# 0    50
# dtype: int64

# %%
print(classification_report(test_data.values, test_predict_new))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.24      0.65      0.36       344
#           1       0.98      0.88      0.93      6002
#
# avg / total       0.94      0.87      0.90      6346

# %%
print(classification_report(test_data.values, test_predict_new2))
# Out:
#              precision    recall  f1-score   support
#
#           0       0.30      0.64      0.41       344
#           1       0.98      0.91      0.94      6002
#
# avg / total       0.94      0.90      0.92      6346

# %% [markdown]
# Precision поднялся на 0.07, а recall упал лишь на 0.01

# %% [markdown]
# ## Отображение результата

# %%
shutil.rmtree('../cache/imgs/')

# %%
os.mkdir('../cache/imgs')

# %%
for i, (r, t) in enumerate(zip(test_predict_new2, test_data.values)):
    im_r = np.zeros((32, 64, 3), dtype='uint8')
    if r == 0:
        im_r[:,:,0] = 255
    elif r == 1:
        im_r[...,2] = 255
    else:
        im_r[...,1] = 255
        
    im_t = np.zeros((32, 64, 3), dtype='uint8')
    if t == 0:
        im_t[:,:,0] = 255
    elif t == 1:
        im_t[...,2] = 255
    else:
        im_t[...,1] = 255
        
    im = np.vstack((im_r, im_t))
    im = Image.fromarray(im)
    im.save('../cache/imgs/test_{:04d}.png'.format(i + 2))
im.save('../cache/imgs/test_{:04d}.png'.format(0))
im.save('../cache/imgs/test_{:04d}.png'.format(1))

# %%
os.system('ffmpeg -r 20 -i ../cache/imgs/test_%04d.png -i ../audio/arhis1.mp3 -vcodec mpeg4 -y ../cache/aa.mp4')
# Out:
# 0
